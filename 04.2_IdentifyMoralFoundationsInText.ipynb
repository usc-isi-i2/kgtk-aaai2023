# %% [markdown]
# <a href="https://colab.research.google.com/github/usc-isi-i2/kgtk-aaai2023/blob/main/04.2_IdentifyMoralFoundationsInText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Identify Moral Foundations in text**
#
# In this notebook we'll be using a pre-trained model to identify moral foundations in text. The text could be anything but preferably of similar length to an average tweet as that is what the model was trained on. In this exmple we will be using Telegram messages as these are publicly availble and relatively easy to export from the desktop Telegram client.
#
# Notes:
#
# *   we are using the `bert-base-uncased` tokenizer
# *   weights are loded from `model_weights.pkl` file
# *   data used is the `translated_messages.json` file
#
# ---
#
# ***Plese make sure that you have the GPU runtime selected for this notebook***
#
#     - select Runtime -> Change runtime type -> Hardware accelerator -> GPU

# %% [markdown]
# # **GPU setup**
#     - check GPU availability
#     - setup torch to use GPU device

# %%
#@title Check gpu availability

# !nvidia-smi


from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('\n\nYour runtime has {:.1f} gigabytes of available RAM\n\n'.format(ram_gb))
# Out:
# Sun Feb  5 22:14:34 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    28W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
#
#
# Your runtime has 13.6 gigabytes of available RAM

# %%
#@title Setup torch to use GPU device

import torch

SEED = 7 #@param {type: "slider", min: 0, max: 100}


# get a count of how many GPU devices area available to us
num_gpu_devices = torch.cuda.device_count()
print("There {} {} GPU device{}".format(
    'is' if num_gpu_devices == 1 else 'are',
    num_gpu_devices,
    '' if num_gpu_devices == 1 else 's' 
))


# manually set the seed when using the gpu
if num_gpu_devices > 0:
    torch.cuda.manual_seed_all(SEED)


# Set the device to use gpu or cpu
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Great, using the GPU!")
else:
    device = torch.device("cpu")
    print("Not great, using the CPU!")
    raise Exception('Check if you have the GPU runtime selected')
# Out:
# There is 1 GPU device
# Great, using the GPU!

# %% [markdown]
# #**Model**#
#     - mount the drive
#     - define labels
#     - install transformers
#     - define model class
#     - load weights into model

# %%
#@title Install the transformers library

# %%time
# %%capture

# !pip install transformers
# Out:
# CPU times: user 59.5 ms, sys: 23.6 ms, total: 83.1 ms
# Wall time: 10.7 s

# %%
#@title Define moral foundation labels

moral_foundation_labels = [
    'care',
    'harm',
    'fairness',
    'cheating',
    'loyalty',
    'betrayal',
    'authority',
    'subversion',
    'sanctity',
    'degradation',
    'non-moral',
]

# %%
#@title Define model class

import pickle
import torch
import transformers


class BERTClass(torch.nn.Module):

    def __init__(self, num_classes):
        super(BERTClass, self).__init__()
        self.l1 = transformers.BertModel.from_pretrained('bert-base-uncased')
        self.dropout = torch.nn.Dropout(0.5)
        self.classifier = torch.nn.Linear(768, num_classes)

    def forward(self, ids, mask, token_type_ids):
        output_1 = self.l1(input_ids=ids, attention_mask=mask, token_type_ids=token_type_ids)
        pooler = self.dropout(output_1.pooler_output)
        output = self.classifier(pooler)
        return output, output_1.last_hidden_state[:, 0, :]

    def save_bert(self, save_path):
        torch.save(self.l1.state_dict(), save_path)

    def save_model(self, save_path):
        with open(save_path, 'wb') as file:
            pickle.dump(self, file)

# %%
#@title Mount Google Drive

# %%time


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# CPU times: user 814 ms, sys: 225 ms, total: 1.04 s
# Wall time: 18 s

# %%
#@title Load the model

# %%time
# %%capture

import torch


model_weights_folder_path = "/content/drive/My Drive/KGTK Tutorial/models/"
model_weights_filename = 'model_weights.pkl'
model_weights_file = model_weights_folder_path + model_weights_filename


model = BERTClass(len(moral_foundation_labels))
model.load_state_dict(torch.load(model_weights_file))
model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# CPU times: user 3.88 s, sys: 2.45 s, total: 6.34 s
# Wall time: 21.3 s

# %% [markdown]
# #**Data**#
#     - mount the drive
#     - load the data
#     - preprosessing data
#         - generate sentences from messages

# %%
#@title Load the data

# %%time

import json


data_file_path = "/content/drive/My Drive/KGTK Tutorial/data/translated_messages.json"
translated_messages = json.load(open(data_file_path, "r"))


# load data from the google drive
data_folder_path = "/content/drive/My Drive/KGTK Tutorial/data/"
data_filename = 'translated_messages.json'
data_file = open(data_folder_path + data_filename)
data = json.load(data_file)


# check how many messages are in that data file
print('{} messages in the data file'.format(len(data['messages'])))
# Out:
# 32 messages in the data file
# CPU times: user 5.31 ms, sys: 1.49 ms, total: 6.8 ms
# Wall time: 787 ms

# %%
#@title Generate a list of sentences

# %%time

from tqdm import tqdm

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize


# split messages up into sentences
for message in tqdm(data['messages']):
    message['sentences'] = sent_tokenize(message['translation']['text'])


# combine all sentences in a single list
sentences = [sentence for message in data['messages'] for sentence in message['sentences']]
len(sentences)


# check how many sentences there are in total
print('{} sentences'.format(len(sentences)))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 100%|██████████| 32/32 [00:00<00:00, 2882.06it/s]
# 82 sentences
# CPU times: user 606 ms, sys: 140 ms, total: 746 ms
# Wall time: 1.79 s

# %% [markdown]
# #**Processing**#
#     - set batch size config varible
#     - handle tokenization
#     - handle validation

# %%
#@title Set VALID_BATCH_SIZE

VALID_BATCH_SIZE = 4 #@param {type: "slider", min: 1, max: 10}

# %%
#@title Handle tokenization

# %%time
# %%capture


import torch
from transformers import BertTokenizer
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset


def handle_tokenize(texts, tokenizer, labels=None):
    encoding = tokenizer(texts, return_tensors='pt', padding=True, truncation=True)
    ids = encoding['input_ids']  # default max_seq 512
    mask = encoding['attention_mask']
    token_type_ids = encoding['token_type_ids']

    if labels:
        targets = torch.tensor(labels)
        return TensorDataset(ids, mask, token_type_ids, targets)
    else:
        return TensorDataset(ids, mask, token_type_ids)


tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
test_set = handle_tokenize(texts=sentences, tokenizer=tokenizer)
testing_loader = DataLoader(test_set, batch_size=VALID_BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# CPU times: user 223 ms, sys: 11.6 ms, total: 235 ms
# Wall time: 5.37 s

# %%
#@title Handle validation

# %%time
# %%capture


import numpy as np
from torch.utils.data import DataLoader


def handle_validation(val_loader, model):
    model.eval()
    fin_outputs = []
    fin_embeddings = []

    with torch.no_grad():
        for step, batch in enumerate(val_loader):
            batch = [r.to(device) for r in batch]

            if len(batch) == 4:
                ids, mask, token_type_ids, label = batch
                labels_in_batch = True
            elif len(batch) == 3:
                ids, mask, token_type_ids = batch
                labels_in_batch = False

            outputs, embeddings = model(ids, mask, token_type_ids)

            # big_val, big_idx = torch.max(outputs.data, dim=1)
            fin_outputs.append(outputs.cpu().detach().numpy())
            fin_embeddings.append(embeddings.cpu().detach().numpy())

    fin_outputs = np.concatenate(fin_outputs, axis=0)
    fin_embeddings = np.concatenate(fin_embeddings, axis=0)

    return fin_outputs, fin_embeddings


testing_loader = DataLoader(test_set, batch_size=VALID_BATCH_SIZE, shuffle=False, num_workers=4)
MF_outputs, _ = handle_validation(testing_loader, model)
MF_outputs = torch.nn.functional.softmax(torch.Tensor(MF_outputs), dim=-1)
MF_outputs = MF_outputs.numpy()
# Out:
# CPU times: user 1.13 s, sys: 594 ms, total: 1.72 s
# Wall time: 4.09 s

# %% [markdown]
# # **Output**
#     - print sentenes
#     - print moral foundation scores

# %%
#@title Print moral foundation scores

# Use NumpyEncoder to convert numpy data to list
# Error: Object of type int64 is not JSON serializable

import json
from tqdm import tqdm


class NumpyEncoder(json.JSONEncoder):
    """ Custom encoder for numpy data types """
    def default(self, obj):
        if isinstance(obj, (np.int_, np.intc, np.intp, np.int8,
                            np.int16, np.int32, np.int64, np.uint8,
                            np.uint16, np.uint32, np.uint64)):

            return int(obj)

        elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
            return float(obj)

        elif isinstance(obj, (np.complex_, np.complex64, np.complex128)):
            return {'real': obj.real, 'imag': obj.imag}

        elif isinstance(obj, (np.ndarray,)):
            return obj.tolist()

        elif isinstance(obj, (np.bool_)):
            return bool(obj)

        elif isinstance(obj, (np.void)):
            return None

        return json.JSONEncoder.default(self, obj)


index = 0
for message in tqdm(data['messages']):
    for sentence in message['sentences']:
        print(sentence)
        print(json.dumps(
            dict(zip(moral_foundation_labels, MF_outputs[index])),
            indent=4,
            ensure_ascii=False,
            cls=NumpyEncoder,    
        ))        print()
        index += 1
# Out:
# 100%|██████████| 32/32 [00:00<00:00, 827.10it/s]
# The controversy over the comedy video, starring three children acting a scene of Mozambican traffic police, continues today, with the journalists' union trading accusations with the provincial prosecutor in Manica.
# {
#     "care": 0.004591815173625946,
#     "harm": 0.031666070222854614,
#     "fairness": 0.014475807547569275,
#     "cheating": 0.08223871141672134,
#     "loyalty": 0.004306383430957794,
#     "betrayal": 0.025487428531050682,
#     "authority": 0.0037580952048301697,
#     "subversion": 0.01861969567835331,
#     "sanctity": 0.0021741881500929594,
#     "degradation": 0.0076093487441539764,
#     "non-moral": 0.805072546005249
# }
#
# Zitamar has subtitled the video in English for our readers to see what the fuss is about, below.
# {
#     "care": 0.002934803254902363,
#     "harm": 0.003654651576653123,
#     "fairness": 0.002017510123550892,
#     "cheating": 0.002186475321650505,
#     "loyalty": 0.0017890357412397861,
#     "betrayal": 0.0012521755415946245,
#     "authority": 0.0009945179335772991,
#     "subversion": 0.0007650618790648878,
#     "sanctity": 0.0011476491345092654,
#     "degradation": 0.0008650497766211629,
#     "non-moral": 0.9823931455612183
# }
#
# Attached to this post are the back-and-forth messages between journalists' union SNJ and the Manica PGR.
# {
#     "care": 0.0033657578751444817,
#     "harm": 0.003930399194359779,
#     "fairness": 0.005012141074985266,
#     "cheating": 0.0045215049758553505,
#     "loyalty": 0.005615058355033398,
#     "betrayal": 0.002664334373548627,
#     "authority": 0.0009958022274076939,
#     "subversion": 0.0013160412199795246,
#     "sanctity": 0.0023395575117319822,
#     "degradation": 0.0008868584409356117,
#     "non-moral": 0.9693526029586792
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# An EU initiative to support private sector electrification projects has set aside €15m for up to 10 projects in Mozambique
#
#  https://zitamar.com/eu-announces-e15m-package-for-electricity-projects-in-mozambique/
# {
#     "care": 0.019868118688464165,
#     "harm": 0.010923091322183609,
#     "fairness": 0.003458180231973529,
#     "cheating": 0.003090554615482688,
#     "loyalty": 0.00937009695917368,
#     "betrayal": 0.003026246326044202,
#     "authority": 0.003590721171349287,
#     "subversion": 0.0018370654433965683,
#     "sanctity": 0.00413816561922431,
#     "degradation": 0.003325583878904581,
#     "non-moral": 0.9373721480369568
# }
#
# The EU today confirmed €20 million to support the continued deployment of Rwanda Defence Force in Cabo Delgado.
# {
#     "care": 0.22958464920520782,
#     "harm": 0.025936705991625786,
#     "fairness": 0.025627005845308304,
#     "cheating": 0.006213285028934479,
#     "loyalty": 0.22833043336868286,
#     "betrayal": 0.020433982834219933,
#     "authority": 0.05888310819864273,
#     "subversion": 0.02667463757097721,
#     "sanctity": 0.016463372856378555,
#     "degradation": 0.006279572378844023,
#     "non-moral": 0.35557323694229126
# }
#
# https://www.consilium.europa.eu/en/press/press-releases/2022/12/01/european-peace-facility-council-adopts-assistance-measures-in-support-of-the-armed-forces-of-five-countries/
# {
#     "care": 0.2382533997297287,
#     "harm": 0.014159145765006542,
#     "fairness": 0.06964156776666641,
#     "cheating": 0.007412306033074856,
#     "loyalty": 0.09954693168401718,
#     "betrayal": 0.00981284398585558,
#     "authority": 0.027087094262242317,
#     "subversion": 0.009216568432748318,
#     "sanctity": 0.036883287131786346,
#     "degradation": 0.004143625032156706,
#     "non-moral": 0.48384323716163635
# }
#
# All of national airline LAM's planes are grounded this morning due to mechanical problems,  Canal de Moçambique  reports  on Facebook  this morning, citing a senior source at the company.
# {
#     "care": 0.005878643598407507,
#     "harm": 0.0822245329618454,
#     "fairness": 0.0037896386347711086,
#     "cheating": 0.04603252187371254,
#     "loyalty": 0.002286267466843128,
#     "betrayal": 0.013115890324115753,
#     "authority": 0.002775340573862195,
#     "subversion": 0.011421437375247478,
#     "sanctity": 0.0017471173778176308,
#     "degradation": 0.005441514775156975,
#     "non-moral": 0.8252869844436646
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# Chinese businessmen operating in Sofala have exported thousands of tonnes of unprocessed timber from Mozambique over recent years, in defiance of a Mozambican ban, Chinese import data shows
#
#  https://zitamar.com/chinese-businessmen-sofala-export-thousands-tonnes-illegal-logs-data-shows/
# {
#     "care": 0.008510085754096508,
#     "harm": 0.19613397121429443,
#     "fairness": 0.010188178159296513,
#     "cheating": 0.20875518023967743,
#     "loyalty": 0.006692181341350079,
#     "betrayal": 0.041863538324832916,
#     "authority": 0.0060213892720639706,
#     "subversion": 0.024703286588191986,
#     "sanctity": 0.00517228152602911,
#     "degradation": 0.02292272076010704,
#     "non-moral": 0.46903711557388306
# }
#
# Zimbabwe is negotiating with Mozambique to purchase an additional 150MW of power, after it was forced to cut generation at the Kariba Dam hydropower plant by at least 50%
#
#  https://zitamar.com/zimbabwe-looks-mozambique-more-power-kariba-hydro-dries-up/
# {
#     "care": 0.010200888849794865,
#     "harm": 0.0160099808126688,
#     "fairness": 0.01765132136642933,
#     "cheating": 0.017783503979444504,
#     "loyalty": 0.008678995072841644,
#     "betrayal": 0.006857908796519041,
#     "authority": 0.0033613801933825016,
#     "subversion": 0.0050837513990700245,
#     "sanctity": 0.006432211957871914,
#     "degradation": 0.0036964803002774715,
#     "non-moral": 0.9042435884475708
# }
#
# President Nyusi yesterday launched Mozambique's e-visa portal, where travellers can apply online for a variety of visas.
# {
#     "care": 0.008409484289586544,
#     "harm": 0.0025883622001856565,
#     "fairness": 0.011762859299778938,
#     "cheating": 0.0037981350906193256,
#     "loyalty": 0.00743522122502327,
#     "betrayal": 0.003232089802622795,
#     "authority": 0.012757721357047558,
#     "subversion": 0.0045062825083732605,
#     "sanctity": 0.0038002782966941595,
#     "degradation": 0.002558163134381175,
#     "non-moral": 0.9391514658927917
# }
#
# The website is available here:  https://evisa.gov.mz/
# {
#     "care": 0.01126430556178093,
#     "harm": 0.0036202198825776577,
#     "fairness": 0.044043924659490585,
#     "cheating": 0.01770785264670849,
#     "loyalty": 0.023957841098308563,
#     "betrayal": 0.00611758092418313,
#     "authority": 0.017221473157405853,
#     "subversion": 0.005239919759333134,
#     "sanctity": 0.02821257710456848,
#     "degradation": 0.00762342382222414,
#     "non-moral": 0.8349908590316772
# }
#
# The leaders of Renamo and MDM, Ossufo Momade and Lutero Simango, will meet at 10am this morning at the MDM headquarters in Maputo.
# {
#     "care": 0.011977586895227432,
#     "harm": 0.009017257951200008,
#     "fairness": 0.006705892737954855,
#     "cheating": 0.0032543414272367954,
#     "loyalty": 0.043401964008808136,
#     "betrayal": 0.008697026409208775,
#     "authority": 0.013218551874160767,
#     "subversion": 0.006364033557474613,
#     "sanctity": 0.0037369788624346256,
#     "degradation": 0.0056396787986159325,
#     "non-moral": 0.8879867196083069
# }
#
# The agenda for the meeting has not been divulged, but they are expected to discuss a possible coalition for elections in 2023 and 2024.
# {
#     "care": 0.008135972544550896,
#     "harm": 0.003630239050835371,
#     "fairness": 0.1148081049323082,
#     "cheating": 0.012233393266797066,
#     "loyalty": 0.0646541640162468,
#     "betrayal": 0.010999270714819431,
#     "authority": 0.02073172852396965,
#     "subversion": 0.008380373939871788,
#     "sanctity": 0.007125155534595251,
#     "degradation": 0.003331766463816166,
#     "non-moral": 0.7459697127342224
# }
#
# Today's newspaper front pages on the streets of Maputo.
# {
#     "care": 0.0013815725687891245,
#     "harm": 0.0025713976938277483,
#     "fairness": 0.001456940546631813,
#     "cheating": 0.0015989416278898716,
#     "loyalty": 0.0025451923720538616,
#     "betrayal": 0.0013014964060857892,
#     "authority": 0.0006807371973991394,
#     "subversion": 0.0006610360578633845,
#     "sanctity": 0.0008372755255550146,
#     "degradation": 0.0007218079408630729,
#     "non-moral": 0.9862436652183533
# }
#
# Photo © Faizal Chauque /  Zitamar News
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.01076890155673027,
#     "harm": 0.004363589454442263,
#     "fairness": 0.0019695558585226536,
#     "cheating": 0.001534835435450077,
#     "loyalty": 0.004780950024724007,
#     "betrayal": 0.0013251465279608965,
#     "authority": 0.002106921747326851,
#     "subversion": 0.0008722893544472754,
#     "sanctity": 0.0018112000543624163,
#     "degradation": 0.0012009951751679182,
#     "non-moral": 0.9692654609680176
# }
#
# Armando Ndambi Guebuza, the eldest son of former president Armando Emilio Guebuza, has been sentenced to 12 years in prison for his part in the Privinvest procurement scandal that saw Mozambique secretly take on $2 billion of debt.
# {
#     "care": 0.012381813488900661,
#     "harm": 0.06923264265060425,
#     "fairness": 0.056791603565216064,
#     "cheating": 0.4908693730831146,
#     "loyalty": 0.007573937997221947,
#     "betrayal": 0.07861173152923584,
#     "authority": 0.013495535589754581,
#     "subversion": 0.05483831465244293,
#     "sanctity": 0.012107361108064651,
#     "degradation": 0.013108893297612667,
#     "non-moral": 0.19098882377147675
# }
#
# The then head of the secret services (SISE), Gregorio Leao, and SISE officer Antonio Carlos do Rosario, have also been sentenced to 12 years each.
# {
#     "care": 0.028459960594773293,
#     "harm": 0.09973178058862686,
#     "fairness": 0.09184969961643219,
#     "cheating": 0.3328447639942169,
#     "loyalty": 0.01200294028967619,
#     "betrayal": 0.050181981176137924,
#     "authority": 0.011649053543806076,
#     "subversion": 0.028313005343079567,
#     "sanctity": 0.037525732070207596,
#     "degradation": 0.009493808262050152,
#     "non-moral": 0.2979472279548645
# }
#
# The sentencing of other suspects is ongoing and can be watched here:  https://play.stv.co.mz/directo-dividas-ocultas-1
#
# Picture: Ndambi Guebuza at his trial in August last year.
# {
#     "care": 0.007305516861379147,
#     "harm": 0.006986263208091259,
#     "fairness": 0.009356627240777016,
#     "cheating": 0.008405587635934353,
#     "loyalty": 0.002103231381624937,
#     "betrayal": 0.003135058330371976,
#     "authority": 0.002859164495021105,
#     "subversion": 0.0017400379292666912,
#     "sanctity": 0.0020972515922039747,
#     "degradation": 0.0018919067224487662,
#     "non-moral": 0.9541193842887878
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# Eleven of the 19 defendants in the so-called hidden debt case, including the son of former president Armando Guebuza, were sentenced today to between 10 and 12 years in prison
#
#  https://zitamar.com/hidden-debts-maputo-court-sentences-11-defendants-to-between-10-and-12-years/
# {
#     "care": 0.015426555648446083,
#     "harm": 0.0684395506978035,
#     "fairness": 0.07198174297809601,
#     "cheating": 0.33739522099494934,
#     "loyalty": 0.005170715507119894,
#     "betrayal": 0.02626633644104004,
#     "authority": 0.007401165086776018,
#     "subversion": 0.012939227744936943,
#     "sanctity": 0.009101837873458862,
#     "degradation": 0.008010704070329666,
#     "non-moral": 0.43786686658859253
# }
#
# Clementina Bomba, Renamo's political delegate to the province of Maputo, has been made the party's secretary general, chosen by party president Ossufo Momade and confirmed at Renamo's National Council meeting in Maputo yesterday.
# {
#     "care": 0.013716480694711208,
#     "harm": 0.005230566952377558,
#     "fairness": 0.025962350890040398,
#     "cheating": 0.0046170735731720924,
#     "loyalty": 0.07050822675228119,
#     "betrayal": 0.009010792709887028,
#     "authority": 0.028572149574756622,
#     "subversion": 0.007920069620013237,
#     "sanctity": 0.005783322267234325,
#     "degradation": 0.0058171809650957584,
#     "non-moral": 0.8228617906570435
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# Read more on this in our Zitamar Daily Briefing later today.
# {
#     "care": 0.004760476294904947,
#     "harm": 0.002961699152365327,
#     "fairness": 0.0034653767943382263,
#     "cheating": 0.002892014104872942,
#     "loyalty": 0.003141238819807768,
#     "betrayal": 0.00170723011251539,
#     "authority": 0.0013398738810792565,
#     "subversion": 0.0010169080924242735,
#     "sanctity": 0.002748899394646287,
#     "degradation": 0.000820756598841399,
#     "non-moral": 0.9751454591751099
# }
#
# Sign up here:  zitamarnews.substack.com
# {
#     "care": 0.011112592183053493,
#     "harm": 0.005870524328202009,
#     "fairness": 0.003418903099372983,
#     "cheating": 0.003121278015896678,
#     "loyalty": 0.004536666441708803,
#     "betrayal": 0.001996094360947609,
#     "authority": 0.0018078512512147427,
#     "subversion": 0.0012221229262650013,
#     "sanctity": 0.002030300907790661,
#     "degradation": 0.0012574588181450963,
#     "non-moral": 0.9636262059211731
# }
#
# Annual inflation has fallen again for the third consecutive month, hitting 11.25% in November compared with  11.8% in the year to October , and 12% in the year to September.
# {
#     "care": 0.005626827012747526,
#     "harm": 0.009636497125029564,
#     "fairness": 0.007858159020543098,
#     "cheating": 0.027606407180428505,
#     "loyalty": 0.0029520783573389053,
#     "betrayal": 0.006133727263659239,
#     "authority": 0.001912036444991827,
#     "subversion": 0.0034762939903885126,
#     "sanctity": 0.005361074116080999,
#     "degradation": 0.0025059410836547613,
#     "non-moral": 0.9269309043884277
# }
#
# Rising food and transport prices remain the main drivers of inflation.
# {
#     "care": 0.014886806719005108,
#     "harm": 0.06544947624206543,
#     "fairness": 0.017090942710638046,
#     "cheating": 0.11382145434617996,
#     "loyalty": 0.005692433565855026,
#     "betrayal": 0.012443838641047478,
#     "authority": 0.0022022519260644913,
#     "subversion": 0.007123659364879131,
#     "sanctity": 0.011406303383409977,
#     "degradation": 0.005709821358323097,
#     "non-moral": 0.7441729307174683
# }
#
# The Bank of Mozambique declined to raise interest rates at  its last monetary policy meeting on 30 November , saying it believed inflation is heading back into single figures next year.
# {
#     "care": 0.014248647727072239,
#     "harm": 0.019751636311411858,
#     "fairness": 0.018613537773489952,
#     "cheating": 0.047358058393001556,
#     "loyalty": 0.007868092507123947,
#     "betrayal": 0.018235649913549423,
#     "authority": 0.0060438415966928005,
#     "subversion": 0.0142047218978405,
#     "sanctity": 0.009104456752538681,
#     "degradation": 0.004467674996703863,
#     "non-moral": 0.8401036262512207
# }
#
# However, the  government has since said  it expects 2023 inflation to be 11.5%.
# {
#     "care": 0.012495342642068863,
#     "harm": 0.01632281020283699,
#     "fairness": 0.025033453479409218,
#     "cheating": 0.060406383126974106,
#     "loyalty": 0.004204073455184698,
#     "betrayal": 0.009423797018826008,
#     "authority": 0.0050963666290044785,
#     "subversion": 0.006779222283512354,
#     "sanctity": 0.0062029073014855385,
#     "degradation": 0.0037946421653032303,
#     "non-moral": 0.85024094581604
# }
#
# Standard Bank's  most recent forecast  for 2022 inflation is 12.1%, and 13.3% in 2023.
# {
#     "care": 0.007207781542092562,
#     "harm": 0.008489404805004597,
#     "fairness": 0.008218880742788315,
#     "cheating": 0.021652285009622574,
#     "loyalty": 0.0024003195576369762,
#     "betrayal": 0.00406530499458313,
#     "authority": 0.002575465478003025,
#     "subversion": 0.0022406280040740967,
#     "sanctity": 0.003359860274940729,
#     "degradation": 0.002559000626206398,
#     "non-moral": 0.937231183052063
# }
#
# The latest inflation report, published by statistics office INE today, is attached.
# {
#     "care": 0.004434139467775822,
#     "harm": 0.002404608065262437,
#     "fairness": 0.014193778857588768,
#     "cheating": 0.007522509898990393,
#     "loyalty": 0.003798185847699642,
#     "betrayal": 0.0024980728048831224,
#     "authority": 0.0025152117013931274,
#     "subversion": 0.0015722892712801695,
#     "sanctity": 0.006142089609056711,
#     "degradation": 0.0012341957772150636,
#     "non-moral": 0.95368492603302
# }
#
# Cabo Ligado Weekly: 5-11 December 2022
#
#  ▪️A multi-day battle for Nguida, Macomia
# ▪️Naparama escalate activities, cause friction with authorities
# ▪️Peaceful Palma remains an exception in the province
#
# Report also  available in Portuguese here
# {
#     "care": 0.01334474515169859,
#     "harm": 0.13150064647197723,
#     "fairness": 0.0037623122334480286,
#     "cheating": 0.016843797639012337,
#     "loyalty": 0.011188511736690998,
#     "betrayal": 0.039304595440626144,
#     "authority": 0.005668258294463158,
#     "subversion": 0.024431079626083374,
#     "sanctity": 0.0025868068914860487,
#     "degradation": 0.01014429796487093,
#     "non-moral": 0.7412248849868774
# }
#
# Mozambique's electricity utility has commissioned a study into battery and pumped hydro storage, as the country looks to roll out more renewable generation
#
#  https://zitamar.com/edm-looks-into-storage-systems-to-accommodate-increase-in-renewable-energy/
# {
#     "care": 0.01328239031136036,
#     "harm": 0.005864770617336035,
#     "fairness": 0.007189042866230011,
#     "cheating": 0.004430276807397604,
#     "loyalty": 0.00482045067474246,
#     "betrayal": 0.0022492611315101385,
#     "authority": 0.002511572325602174,
#     "subversion": 0.0015838867984712124,
#     "sanctity": 0.006234082393348217,
#     "degradation": 0.0023881413508206606,
#     "non-moral": 0.9494462013244629
# }
#
# Mozambique's GDP grew 3.6% in the 12 months to the end of September 2022, driven by growth in the hospitality sector, mining extractive industries, as well as transport and communications.
# {
#     "care": 0.03080316074192524,
#     "harm": 0.00966473389416933,
#     "fairness": 0.015827596187591553,
#     "cheating": 0.013350172899663448,
#     "loyalty": 0.015861768275499344,
#     "betrayal": 0.006196056958287954,
#     "authority": 0.008166261948645115,
#     "subversion": 0.003919660113751888,
#     "sanctity": 0.019916685298085213,
#     "degradation": 0.005182329099625349,
#     "non-moral": 0.8711116313934326
# }
#
# In the first and second quarters of 2022, annual GDP growth was 4.14% and 4.59% respectively.
# {
#     "care": 0.008899475447833538,
#     "harm": 0.007242201361805201,
#     "fairness": 0.017573995515704155,
#     "cheating": 0.01909942924976349,
#     "loyalty": 0.004838602617383003,
#     "betrayal": 0.005889735650271177,
#     "authority": 0.005076351575553417,
#     "subversion": 0.004096130840480328,
#     "sanctity": 0.006692712195217609,
#     "degradation": 0.0030004552099853754,
#     "non-moral": 0.9175909161567688
# }
#
# According to the 2022 State Budget, the government forecast a 2.9% economic growth for this year.
# {
#     "care": 0.009961975738406181,
#     "harm": 0.0046493071131408215,
#     "fairness": 0.025828374549746513,
#     "cheating": 0.010430258698761463,
#     "loyalty": 0.005895676556974649,
#     "betrayal": 0.004391212947666645,
#     "authority": 0.007382138166576624,
#     "subversion": 0.003345734439790249,
#     "sanctity": 0.005913910456001759,
#     "degradation": 0.0024081694427877665,
#     "non-moral": 0.9197932481765747
# }
#
# The statistics from the national statistics institute (INE) are attached.
# {
#     "care": 0.00455420883372426,
#     "harm": 0.0030885208398103714,
#     "fairness": 0.008405287750065327,
#     "cheating": 0.005150881130248308,
#     "loyalty": 0.004290668293833733,
#     "betrayal": 0.0022019040770828724,
#     "authority": 0.0020225653424859047,
#     "subversion": 0.0010997006902471185,
#     "sanctity": 0.00500662112608552,
#     "degradation": 0.001426679315045476,
#     "non-moral": 0.9627529382705688
# }
#
# Mozambique's energy regulator, Arene, yesterday announced a 7% cut in the retail price of cooking gas, and kept the price of all other fuels the same.
# {
#     "care": 0.01111519429832697,
#     "harm": 0.014596136286854744,
#     "fairness": 0.02520221844315529,
#     "cheating": 0.028367143124341965,
#     "loyalty": 0.004084721207618713,
#     "betrayal": 0.007959956303238869,
#     "authority": 0.008092844858765602,
#     "subversion": 0.009965244680643082,
#     "sanctity": 0.0049859569407999516,
#     "degradation": 0.00415656715631485,
#     "non-moral": 0.881473958492279
# }
#
# The move came despite protests from fuel retailers who say the current prices are unsustainably low, and could lead to shortages over the festive period.
# {
#     "care": 0.01592388190329075,
#     "harm": 0.05902643874287605,
#     "fairness": 0.007960088551044464,
#     "cheating": 0.03672528266906738,
#     "loyalty": 0.006033079698681831,
#     "betrayal": 0.010338084772229195,
#     "authority": 0.004852732177823782,
#     "subversion": 0.010863800533115864,
#     "sanctity": 0.007226589135825634,
#     "degradation": 0.006679261568933725,
#     "non-moral": 0.8343709111213684
# }
#
# The full statement from Arene is attached.
# {
#     "care": 0.0018142818007618189,
#     "harm": 0.0022918828763067722,
#     "fairness": 0.004891218151897192,
#     "cheating": 0.004056132398545742,
#     "loyalty": 0.0020921954419463873,
#     "betrayal": 0.001734385034069419,
#     "authority": 0.001541520468890667,
#     "subversion": 0.001171710784547031,
#     "sanctity": 0.002442052587866783,
#     "degradation": 0.0009636910981498659,
#     "non-moral": 0.977000892162323
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# A Rwandan company has won an $800,000 contract to upgrade a resettlement village for people forced to move by the Mozambique LNG project in Cabo Delgado
#
#  https://zitamar.com/rwandan-company-wins-800k-mozambique-lng-resettlement-deal/
# {
#     "care": 0.03863692656159401,
#     "harm": 0.030966676771640778,
#     "fairness": 0.005716858897358179,
#     "cheating": 0.009973554871976376,
#     "loyalty": 0.00864116009324789,
#     "betrayal": 0.004311899188905954,
#     "authority": 0.0021808473393321037,
#     "subversion": 0.00196936447173357,
#     "sanctity": 0.007111435290426016,
#     "degradation": 0.0030905562452971935,
#     "non-moral": 0.8874006271362305
# }
#
# "Independent journalism in Mozambique is facing considerable legal, political, and economic pressures as the country’s hard-fought democratic gains of the past three decades come under increasing strain," the International Press Institute (IPI) warned this week.
# {
#     "care": 0.012705184519290924,
#     "harm": 0.029489409178495407,
#     "fairness": 0.20171351730823517,
#     "cheating": 0.17423386871814728,
#     "loyalty": 0.011351236142218113,
#     "betrayal": 0.036013051867485046,
#     "authority": 0.012999029830098152,
#     "subversion": 0.03688901290297508,
#     "sanctity": 0.008364466950297356,
#     "degradation": 0.0047112987376749516,
#     "non-moral": 0.47152993083000183
# }
#
# The IPI said it shared concerns voiced by civil society groups and journalists about the decline in press freedom and the worsening climate for independent journalism since President Nyusi took office in 2015.
# {
#     "care": 0.024037932977080345,
#     "harm": 0.014923812821507454,
#     "fairness": 0.6417247653007507,
#     "cheating": 0.06916461139917374,
#     "loyalty": 0.012419482693076134,
#     "betrayal": 0.018960285931825638,
#     "authority": 0.01825404167175293,
#     "subversion": 0.02960795722901821,
#     "sanctity": 0.008958297781646252,
#     "degradation": 0.0026338943280279636,
#     "non-moral": 0.15931491553783417
# }
#
# "In our assessment, swift action is needed in order to bolster protections for press freedom and to reinforce support for key democratic institutions in Mozambique," it said.
# {
#     "care": 0.031903646886348724,
#     "harm": 0.004478003829717636,
#     "fairness": 0.7939462065696716,
#     "cheating": 0.013344431295990944,
#     "loyalty": 0.030109381303191185,
#     "betrayal": 0.00961990561336279,
#     "authority": 0.044007983058691025,
#     "subversion": 0.01589948497712612,
#     "sanctity": 0.010783826000988483,
#     "degradation": 0.002108554355800152,
#     "non-moral": 0.04379846900701523
# }
#
# A key concern is the uncertain and unclear legal and regulatory environment under which the country’s media operate, including draft media laws which are currently on the agenda for consideration in this parliamentary session.
# {
#     "care": 0.006313552614301443,
#     "harm": 0.011611182242631912,
#     "fairness": 0.22166867554187775,
#     "cheating": 0.15685950219631195,
#     "loyalty": 0.005542281083762646,
#     "betrayal": 0.022348757833242416,
#     "authority": 0.0391705185174942,
#     "subversion": 0.040806449949741364,
#     "sanctity": 0.004855867475271225,
#     "degradation": 0.009243717417120934,
#     "non-moral": 0.48157960176467896
# }
#
# A specific list of recommendations is in the attached images.
# {
#     "care": 0.005366967525333166,
#     "harm": 0.00480381166562438,
#     "fairness": 0.003005111124366522,
#     "cheating": 0.002630348317325115,
#     "loyalty": 0.001774188713170588,
#     "betrayal": 0.0013362342724576592,
#     "authority": 0.002248539123684168,
#     "subversion": 0.001070322236046195,
#     "sanctity": 0.0016595269553363323,
#     "degradation": 0.0011451429454609752,
#     "non-moral": 0.9749597311019897
# }
#
# The  full report is available online here .
# {
#     "care": 0.008431597612798214,
#     "harm": 0.005606010556221008,
#     "fairness": 0.01629948429763317,
#     "cheating": 0.011097737587988377,
#     "loyalty": 0.007052415516227484,
#     "betrayal": 0.003762811189517379,
#     "authority": 0.003667592303827405,
#     "subversion": 0.0027977467980235815,
#     "sanctity": 0.006311391945928335,
#     "degradation": 0.001950914622284472,
#     "non-moral": 0.9330222606658936
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# If Mozal's contract to buy power from Cahora Bassa hydro is not renewed, it could mean its aluminium is too carbon-intensive under new EU rules
#
#  https://zitamar.com/mozal-in-talks-to-keep-hydropower-supply-as-eu-approves-carbon-levy-on-imports/
# {
#     "care": 0.00629708357155323,
#     "harm": 0.02741417847573757,
#     "fairness": 0.010654808953404427,
#     "cheating": 0.0322001650929451,
#     "loyalty": 0.004777137190103531,
#     "betrayal": 0.005747202318161726,
#     "authority": 0.0029776152223348618,
#     "subversion": 0.003726339666172862,
#     "sanctity": 0.0032823767978698015,
#     "degradation": 0.004355539567768574,
#     "non-moral": 0.8985675573348999
# }
#
# UPDATE:  https://t.me/zitamarlive/2374
#
# The last remaining Renamo base in Gorongosa, the movement's traditional redoubt in the centre of Mozambique, was closed today, and 350 Renamo combatants there, including 50 women, formally demobilised.
# {
#     "care": 0.033785492181777954,
#     "harm": 0.050959113985300064,
#     "fairness": 0.01806012913584709,
#     "cheating": 0.016497798264026642,
#     "loyalty": 0.12352209538221359,
#     "betrayal": 0.042016349732875824,
#     "authority": 0.00701440405100584,
#     "subversion": 0.020590079948306084,
#     "sanctity": 0.015930792316794395,
#     "degradation": 0.006942435633391142,
#     "non-moral": 0.6646813154220581
# }
#
# The event marked the end of the demobilisation phase of the disarmament, demobilisation, and reintegration process signed by President Filipe Nyusi and Renamo leader Ossufo Momade in 2019.
# {
#     "care": 0.0420687273144722,
#     "harm": 0.036686401814222336,
#     "fairness": 0.027749691158533096,
#     "cheating": 0.008311571553349495,
#     "loyalty": 0.038839034736156464,
#     "betrayal": 0.01889686845242977,
#     "authority": 0.01652868278324604,
#     "subversion": 0.019384421408176422,
#     "sanctity": 0.02336946502327919,
#     "degradation": 0.010473577305674553,
#     "non-moral": 0.757691502571106
# }
#
# Voice of America has a report from Gorongosa:  https://www.voaportugues.com/a/última-base-da-renamo-encerrada-na-gorongosa-apesar-do-descontentamento-de-guerrilheiros/6882520.html
#
#  Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.014783351682126522,
#     "harm": 0.006295943167060614,
#     "fairness": 0.002220018533989787,
#     "cheating": 0.001707167481072247,
#     "loyalty": 0.011688578873872757,
#     "betrayal": 0.0018503067549318075,
#     "authority": 0.0029030148871243,
#     "subversion": 0.0011630650842562318,
#     "sanctity": 0.0026112624909728765,
#     "degradation": 0.0020034443587064743,
#     "non-moral": 0.9527738690376282
# }
#
# CORRECTION
#
# Today's demobilisation of 350 Renamo guerrillas did not in fact go ahead, as the guerrillas and the Renamo leadership boycotted the planned event in Gorongosa.
# {
#     "care": 0.008264214731752872,
#     "harm": 0.06692520529031754,
#     "fairness": 0.003790493356063962,
#     "cheating": 0.01250198483467102,
#     "loyalty": 0.018031755462288857,
#     "betrayal": 0.03553402051329613,
#     "authority": 0.004030213691294193,
#     "subversion": 0.01826147548854351,
#     "sanctity": 0.0029015846084803343,
#     "degradation": 0.008935239166021347,
#     "non-moral": 0.8208238482475281
# }
#
# The boycott was due to the fact that the promised pension fund for demobilised fighters has not yet materialised.
# {
#     "care": 0.004000190179795027,
#     "harm": 0.017076855525374413,
#     "fairness": 0.003938229288905859,
#     "cheating": 0.015785297378897667,
#     "loyalty": 0.013292020186781883,
#     "betrayal": 0.011240492574870586,
#     "authority": 0.0019490054110065103,
#     "subversion": 0.004155158530920744,
#     "sanctity": 0.0014274378772825003,
#     "degradation": 0.0024385324213653803,
#     "non-moral": 0.924696683883667
# }
#
# We apologise for the error.
# {
#     "care": 0.004333158954977989,
#     "harm": 0.0021385157015174627,
#     "fairness": 0.004207013174891472,
#     "cheating": 0.002632708055898547,
#     "loyalty": 0.006402717903256416,
#     "betrayal": 0.0023885981645435095,
#     "authority": 0.0040824078023433685,
#     "subversion": 0.0017644412582740188,
#     "sanctity": 0.002877613063901663,
#     "degradation": 0.001041001407429576,
#     "non-moral": 0.9681318402290344
# }
#
# President Nyusi is giving his State of the Nation address to parliament in Maputo, now.
# {
#     "care": 0.003137401770800352,
#     "harm": 0.0020767494570463896,
#     "fairness": 0.002449003979563713,
#     "cheating": 0.0011919550597667694,
#     "loyalty": 0.006385465618222952,
#     "betrayal": 0.002207662910223007,
#     "authority": 0.003761506639420986,
#     "subversion": 0.002192710991948843,
#     "sanctity": 0.0019813270773738623,
#     "degradation": 0.0017990346532315016,
#     "non-moral": 0.9728171229362488
# }
#
# Watch live on Facebook courtesy of SucessoTV:  https://www.facebook.com/tvsucessomoz/live_videos/?ref=page_internal
#
# Or listen on Radio Moçambique, on  www.rm.co.mz  or through Podcast Addict:  https://podcastaddict.com/radio/10151
#
#  Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.006166448816657066,
#     "harm": 0.003405270865187049,
#     "fairness": 0.0013971158768981695,
#     "cheating": 0.0013029912952333689,
#     "loyalty": 0.0029611517675220966,
#     "betrayal": 0.0009791558841243386,
#     "authority": 0.001394725637510419,
#     "subversion": 0.0006999092875048518,
#     "sanctity": 0.0012940163724124432,
#     "degradation": 0.0010407429654151201,
#     "non-moral": 0.9793586134910583
# }
#
# President Nyusi announced in his state of the nation address this morning that a working group will be established to discuss the viability or otherwise of holding district-level elections in 2024.
# {
#     "care": 0.014956094324588776,
#     "harm": 0.004646097309887409,
#     "fairness": 0.09956476092338562,
#     "cheating": 0.009751244448125362,
#     "loyalty": 0.024006247520446777,
#     "betrayal": 0.011412924155592918,
#     "authority": 0.07452183216810226,
#     "subversion": 0.018158674240112305,
#     "sanctity": 0.0059390440583229065,
#     "degradation": 0.007323375903069973,
#     "non-moral": 0.7297197580337524
# }
#
# The working group will be made up of "different members of society", and its conclusions will be submitted to parliament for final approval, Nyusi said.
# {
#     "care": 0.009581184014678001,
#     "harm": 0.0032096204813569784,
#     "fairness": 0.11077899485826492,
#     "cheating": 0.010695195756852627,
#     "loyalty": 0.01829385943710804,
#     "betrayal": 0.006581710651516914,
#     "authority": 0.01750185899436474,
#     "subversion": 0.004756608046591282,
#     "sanctity": 0.00973601546138525,
#     "degradation": 0.0028044069185853004,
#     "non-moral": 0.8060606122016907
# }
#
# Up to now, district administrators have always been appointed by government but the most recent peace deal with Renamo provided for them to be elected.
# {
#     "care": 0.029973382130265236,
#     "harm": 0.019567303359508514,
#     "fairness": 0.0781138464808464,
#     "cheating": 0.02327794022858143,
#     "loyalty": 0.03928108140826225,
#     "betrayal": 0.044312555342912674,
#     "authority": 0.28139904141426086,
#     "subversion": 0.07776817679405212,
#     "sanctity": 0.01215716078877449,
#     "degradation": 0.033254899084568024,
#     "non-moral": 0.3608945310115814
# }
#
# Since then, many arguments have been made that they should not go ahead.
# {
#     "care": 0.0030898326076567173,
#     "harm": 0.014158269390463829,
#     "fairness": 0.010793635621666908,
#     "cheating": 0.018481332808732986,
#     "loyalty": 0.0027796044014394283,
#     "betrayal": 0.004265632480382919,
#     "authority": 0.002389529487118125,
#     "subversion": 0.001919836737215519,
#     "sanctity": 0.00286765955388546,
#     "degradation": 0.0019155855989083648,
#     "non-moral": 0.9373390674591064
# }
#
# Cancelling them may require a revision of the Mozambican constitution, however.
# {
#     "care": 0.004088033456355333,
#     "harm": 0.013709282502532005,
#     "fairness": 0.06811274588108063,
#     "cheating": 0.08737735450267792,
#     "loyalty": 0.0071400669403374195,
#     "betrayal": 0.01824951358139515,
#     "authority": 0.03474048152565956,
#     "subversion": 0.036479026079177856,
#     "sanctity": 0.005876962561160326,
#     "degradation": 0.017740396782755852,
#     "non-moral": 0.7064862847328186
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# South Africa's Supreme Court of Appeal has refused to hear an appeal by Mozambique's government against a decision to extradite former finance minister Manuel Chang to the United States of America.
# {
#     "care": 0.007191674783825874,
#     "harm": 0.03401143103837967,
#     "fairness": 0.08567111194133759,
#     "cheating": 0.5142737627029419,
#     "loyalty": 0.004764828365296125,
#     "betrayal": 0.04779643565416336,
#     "authority": 0.016152752563357353,
#     "subversion": 0.04757213965058327,
#     "sanctity": 0.005868369713425636,
#     "degradation": 0.014938960783183575,
#     "non-moral": 0.22175851464271545
# }
#
# In a decision published today, the court said: "The application for leave to appeal is dismissed with costs on the grounds that there is no reasonable prospect of success in an appeal and there is no other compelling reason why an appeal should be heard."
# {
#     "care": 0.008834726177155972,
#     "harm": 0.014594032429158688,
#     "fairness": 0.36103355884552,
#     "cheating": 0.29477259516716003,
#     "loyalty": 0.010674724355340004,
#     "betrayal": 0.013728022575378418,
#     "authority": 0.019732484593987465,
#     "subversion": 0.01075612660497427,
#     "sanctity": 0.022676018998026848,
#     "degradation": 0.007324684411287308,
#     "non-moral": 0.2358730137348175
# }
#
# The Mozambique government is now expected to appeal to South Africa's Constitutional Court, the highest court in the land.
# {
#     "care": 0.007372657302767038,
#     "harm": 0.010411873459815979,
#     "fairness": 0.48264458775520325,
#     "cheating": 0.16886644065380096,
#     "loyalty": 0.007425487507134676,
#     "betrayal": 0.015280471183359623,
#     "authority": 0.031005380675196648,
#     "subversion": 0.018612051382660866,
#     "sanctity": 0.007774456404149532,
#     "degradation": 0.00809759646654129,
#     "non-moral": 0.24250905215740204
# }
#
# Today's decision is attached.
# {
#     "care": 0.002249425509944558,
#     "harm": 0.0015917847631499171,
#     "fairness": 0.016464464366436005,
#     "cheating": 0.004701119381934404,
#     "loyalty": 0.0037797316908836365,
#     "betrayal": 0.0022021280601620674,
#     "authority": 0.00485971849411726,
#     "subversion": 0.0018319111550226808,
#     "sanctity": 0.004647005815058947,
#     "degradation": 0.0011949617182835937,
#     "non-moral": 0.9564778208732605
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# The UK has updated its travel advice for Mozambique, now advising against all but essential travel to the whole of Cabo Delgado, including the capital Pemba, and districts of Montepuez, Balama, and Namuno, as well as the districts of Memba and Erati in Nampula province.
# {
#     "care": 0.04818825423717499,
#     "harm": 0.019346466287970543,
#     "fairness": 0.006634786259382963,
#     "cheating": 0.006610977929085493,
#     "loyalty": 0.014702378772199154,
#     "betrayal": 0.005573487840592861,
#     "authority": 0.01526540145277977,
#     "subversion": 0.005037462338805199,
#     "sanctity": 0.0069367242977023125,
#     "degradation": 0.004529502708464861,
#     "non-moral": 0.8671745657920837
# }
#
# The Foreign Office still advises against all travel to
# the districts of Mueda, Nangade, Palma, Mocimboa da Praia, Muidumbe, Meluco, Macomia, Quissanga and Ibo.
# {
#     "care": 0.028581131249666214,
#     "harm": 0.029955754056572914,
#     "fairness": 0.0035718237049877644,
#     "cheating": 0.004611143842339516,
#     "loyalty": 0.012584149837493896,
#     "betrayal": 0.008037779480218887,
#     "authority": 0.010392721742391586,
#     "subversion": 0.006530302111059427,
#     "sanctity": 0.0036364439874887466,
#     "degradation": 0.005591083317995071,
#     "non-moral": 0.8865077495574951
# }
#
# Until last week, there was an exception for the town of Palma and the Afungi peninsula, home of the Mozambique LNG project, which were included under "all but essential travel".
# {
#     "care": 0.007191088516265154,
#     "harm": 0.025111790746450424,
#     "fairness": 0.002014815341681242,
#     "cheating": 0.006810574792325497,
#     "loyalty": 0.0038301830645650625,
#     "betrayal": 0.0037154536694288254,
#     "authority": 0.0027858756948262453,
#     "subversion": 0.0025928637478500605,
#     "sanctity": 0.0018731660675257444,
#     "degradation": 0.003670646110549569,
#     "non-moral": 0.9404035210609436
# }
#
# Now, the UK advises against all travel there.
# {
#     "care": 0.015485954470932484,
#     "harm": 0.06902008503675461,
#     "fairness": 0.004649185575544834,
#     "cheating": 0.013594779185950756,
#     "loyalty": 0.004030931740999222,
#     "betrayal": 0.005524244159460068,
#     "authority": 0.0023592214565724134,
#     "subversion": 0.003194863209500909,
#     "sanctity": 0.004104981664568186,
#     "degradation": 0.004441704601049423,
#     "non-moral": 0.8735941052436829
# }
#
# The updated advice can be seen here:  https://www.gov.uk/foreign-travel-advice/mozambique
#
# The version from a week ago is  archived here .
# {
#     "care": 0.019958017393946648,
#     "harm": 0.004774568136781454,
#     "fairness": 0.011538846418261528,
#     "cheating": 0.007458530832082033,
#     "loyalty": 0.02170288749039173,
#     "betrayal": 0.004303414840251207,
#     "authority": 0.01117012556642294,
#     "subversion": 0.0039250170812010765,
#     "sanctity": 0.01380620151758194,
#     "degradation": 0.003927943296730518,
#     "non-moral": 0.8974344730377197
# }
#
# Follow Zitamar on our  Live Blog , on  Twitter , and at  Zitamar.com
#
# Sign up for our newsletter at  zitamarnews.substack.com
# {
#     "care": 0.022667795419692993,
#     "harm": 0.00594602944329381,
#     "fairness": 0.003854914102703333,
#     "cheating": 0.0027902796864509583,
#     "loyalty": 0.01090760063380003,
#     "betrayal": 0.001976698637008667,
#     "authority": 0.0031808943022042513,
#     "subversion": 0.0014299507020041347,
#     "sanctity": 0.003773757955059409,
#     "degradation": 0.00165054970420897,
#     "non-moral": 0.9418214559555054
# }
#
# Renamo leader Ossufo Momade says he is still in Gorongosa, meeting with guerrillas there to explain why the party boycotted the closing of the DDR process on Monday.
# {
#     "care": 0.005380846560001373,
#     "harm": 0.01990174502134323,
#     "fairness": 0.004827388096600771,
#     "cheating": 0.00862927082926035,
#     "loyalty": 0.02310383878648281,
#     "betrayal": 0.023991918191313744,
#     "authority": 0.004641291685402393,
#     "subversion": 0.020135188475251198,
#     "sanctity": 0.003169222502037883,
#     "degradation": 0.004542880691587925,
#     "non-moral": 0.881676435470581
# }
#
# https://twitter.com/Ossufo_MomadeRN/status/1605661395223281665
# {
#     "care": 0.01297222450375557,
#     "harm": 0.0063867210410535336,
#     "fairness": 0.0020141685381531715,
#     "cheating": 0.001645468408241868,
#     "loyalty": 0.0024116993881762028,
#     "betrayal": 0.0012313867919147015,
#     "authority": 0.0014604864409193397,
#     "subversion": 0.0009084228076972067,
#     "sanctity": 0.0016980655491352081,
#     "degradation": 0.001368990633636713,
#     "non-moral": 0.967902421951294
# }
#
# Off-grid renewable energy projects will be vital in Mozambique's quest for 100% electrification — and can better withstand climate disasters, without contributing to them
#
#  https://zitamar.com/mozambique-looks-to-off-grid-systems-to-provide-energy-for-all/
# {
#     "care": 0.27444708347320557,
#     "harm": 0.037058986723423004,
#     "fairness": 0.04893804341554642,
#     "cheating": 0.012287617661058903,
#     "loyalty": 0.026203785091638565,
#     "betrayal": 0.0077166748233139515,
#     "authority": 0.013502849265933037,
#     "subversion": 0.006887928582727909,
#     "sanctity": 0.02749435044825077,
#     "degradation": 0.00438811955973506,
#     "non-moral": 0.5410745739936829
# }
#
# Insurgents raided a Mozambican security forces base at Chai, in Macomia district, on Tuesday night, seizing a large array of weapons and ammunition
#
#  https://zitamar.com/insurgents-capture-large-munitions-stockpile-at-chai/
# {
#     "care": 0.04697238653898239,
#     "harm": 0.18157929182052612,
#     "fairness": 0.021945426240563393,
#     "cheating": 0.06186186894774437,
#     "loyalty": 0.06863109767436981,
#     "betrayal": 0.12018956243991852,
#     "authority": 0.023974759504199028,
#     "subversion": 0.11833027750253677,
#     "sanctity": 0.02056010067462921,
#     "degradation": 0.02421540394425392,
#     "non-moral": 0.31173986196517944
# }
#
# Renamo's new secretary general, Clementina Bomba, made a statement in a press conference this afternoon denying reports that part leader Ossufo Momade has been captured by Renamo guerrillas in Gorongosa.
# {
#     "care": 0.025243550539016724,
#     "harm": 0.07240108400583267,
#     "fairness": 0.033491022884845734,
#     "cheating": 0.044657666236162186,
#     "loyalty": 0.08734305948019028,
#     "betrayal": 0.11655254662036896,
#     "authority": 0.014609202742576599,
#     "subversion": 0.07143013179302216,
#     "sanctity": 0.013850471936166286,
#     "degradation": 0.014012587256729603,
#     "non-moral": 0.50640869140625
# }
#
# The full statement is attached.
# {
#     "care": 0.0026562800630927086,
#     "harm": 0.0021137588191777468,
#     "fairness": 0.01696738600730896,
#     "cheating": 0.006178189534693956,
#     "loyalty": 0.00389567157253623,
#     "betrayal": 0.002381232101470232,
#     "authority": 0.00450596259906888,
#     "subversion": 0.002046938519924879,
#     "sanctity": 0.005386960692703724,
#     "degradation": 0.001410186174325645,
#     "non-moral": 0.9524574279785156
# }
